# %%
import pandas as pd

# %%
df = pd.read_csv('raw.csv')

# %%
df
# Out:
#      Vaakuna  Kunta-nro[4] Kunnan nimi   Nimitys Kielet  \
# 0        NaN            20        Akaa  kaupunki  suomi
# 1        NaN             5    Alajärvi  kaupunki  suomi
# 2        NaN             9   Alavieska     kunta  suomi
# 3        NaN            10      Alavus  kaupunki  suomi
# 4        NaN            16    Asikkala     kunta  suomi
# ..       ...           ...         ...       ...    ...
# 304      NaN           977   Ylivieska  kaupunki  suomi
# 305      NaN           980    Ylöjärvi  kaupunki  suomi
# 306      NaN           981       Ypäjä     kunta  suomi
# 307      NaN           989      Ähtäri  kaupunki  suomi
# 308      NaN           992   Äänekoski  kaupunki  suomi
#
#                   Kuntakeskus           Maakunta                   Seutukunta  \
# 0      Toijalan keskustaajama          Pirkanmaa  Etelä-Pirkanmaan seutukunta
# 1     Alajärven keskustaajama    Etelä-Pohjanmaa       Järviseudun seutukunta
# ...

# %%
kunnan_nimi = df['Kunnan nimi']
maakunta = df['Maakunta']

# %%
#set(maakunta.tolist())
maakunta.drop_duplicates(inplace = True)

# %%
kunnan_nimi.to_csv('output/kunnat.txt', index=False, header=False)
maakunta.to_csv('output/maakunnat.txt', index=False, header=False)
